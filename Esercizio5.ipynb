# %%
import pandas as pd 
import matplotlib as plt
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("./Datasets5/supermarkets.csv")

# %%
df
# Out:
#                                 FacilityName         Municipality  LONGITUDE  \
# 0                                     Sobeys       St. Catharines -79.229554
# 1                                    Sobeys               Welland -79.287023
# 2                   Real Canadian Superstore              Grimsby -79.592071
# 3   Outlet Collection at Niagara- Davids Tea  Niagara-on-the-Lake -79.172006
# 4                    No Frills - Supermarket            Fort Erie -78.943567
# 5                                Food Basics              Welland -79.272214
# 6                                Giant Tiger        Niagara Falls -79.097458
# 7                      Commisso's Fresh Food        Niagara Falls -79.097458
# 8                         Busy Bee Food Mart        Niagara Falls -79.073331
# 9                                   Lococo's        Niagara Falls -79.074096
# 10                                   Walmart       St. Catharines -79.214388
# ...

# %%
dataMunicipi = df[df["Municipality"]=="St. Catharines"]

# %%
dataMunicipi
# Out:
#                       FacilityName    Municipality  LONGITUDE   LATITUDE  \
# 0                           Sobeys  St. Catharines -79.229554  43.187516
# 10                         Walmart  St. Catharines -79.214388  43.176295
# 11     No Frills - Dennis' (#3148)  St. Catharines -79.214388  43.176295
# 12                     Pistachio's  St. Catharines -79.210606  43.176056
# 13                    Meg Africana  St. Catharines -79.237872  43.167024
# 14                     Food Basics  St. Catharines -79.215331  43.148576
# 21                         FreshCo  St. Catharines -79.208833  43.178189
# 22        El Bodegon Latin Grocery  St. Catharines -79.209630  43.179552
# 24             Polonez Meat Market  St. Catharines -79.227323  43.175326
# 26                     Food Basics  St. Catharines -79.241627  43.176357
# 27           Dinh Dinh Asian Foods  St. Catharines -79.240672  43.164186
# 28                           Zehrs  St. Catharines -79.243772  43.177470
# ...

# %%
dataMunicipi["FacilityName"].unique()
# Out:
# array(['Sobeys', 'Walmart', "No Frills - Dennis' (#3148)", "Pistachio's",
#        'Meg Africana', 'Food Basics', 'FreshCo',
#        'El Bodegon Latin Grocery', 'Polonez Meat Market',
#        'Dinh Dinh Asian Foods', 'Zehrs', 'Antipastos',
#        'Real Canadian Superstore', 'Bamboo Natural Food Market Inc',
#        'Costco'], dtype=object)

# %%
df["GSmartID"].duplicated().sum()
# Out:
# 2
